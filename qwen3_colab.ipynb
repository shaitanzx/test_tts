# %%
# @markdown # Qwen3_TTS
# @markdown # Run for start

# %cd /content
# !pip install pygit2==1.15.1
# !apt-get install -y sox
# %cd /content
# !git clone https://github.com/shaitanzx/qwen3_tts.git
# %cd /content/qwen3_tts
# !python entry_with_update.py --share
